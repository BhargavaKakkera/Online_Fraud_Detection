# %%
#importing the dependencies

import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
#converting zip file into csv file

from zipfile import ZipFile
dataset = '/content/onlinefraud.csv.zip'

with ZipFile(dataset,'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
# Out:
# The dataset is extracted

# %%
#loading the dataset into a pandas dataframe
dataset = pd.read_csv('/content/onlinefraud.csv')

# %%
dataset.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
dataset.tail()
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 6362615             0.0   C776919290            0.00       339682.13        1
# 6362616             0.0  C1881841831            0.00            0.00        1
# 6362617             0.0  C1365125890        68488.84      6379898.11        1
# 6362618             0.0  C2080388513            0.00            0.00        1
# 6362619             0.0   C873221189      6510099.11      7360101.63        1
#
#          isFlaggedFraud
# 6362615               0
# 6362616               0
# 6362617               0
# 6362618               0
# 6362619               0

# %%
dataset.shape
# Out:
# (6362620, 11)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
dataset.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
dataset['isFraud'].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
#converting type column into labels

label_encoder = LabelEncoder()
label_encoder.fit(dataset['type'])
# Out:
# LabelEncoder()

# %%
dataset['type'] = label_encoder.transform(dataset['type'])

# %%
dataset.head()
# Out:
#    step  type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1     3   9839.64  C1231006815       170136.0       160296.36
# 1     1     3   1864.28  C1666544295        21249.0        19384.72
# 2     1     4    181.00  C1305486145          181.0            0.00
# 3     1     1    181.00   C840083671          181.0            0.00
# 4     1     3  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
dataset['type'].value_counts()
# Out:
# type
# 1    2237500
# 3    2151495
# 0    1399284
# 4     532909
# 2      41432
# Name: count, dtype: int64

# %%
#separating the data as legal and fraud for analysis

legal = dataset[dataset.isFraud == 0]
fraud = dataset[dataset.isFraud == 1]

# %%
print(legal.shape)
print(fraud.shape)
# Out:
# (6354407, 11)
# (8213, 11)

# %%
legal.describe()
# Out:
#                step          type        amount  oldbalanceOrg  \
# count  6.354407e+06  6.354407e+06  6.354407e+06   6.354407e+06
# mean   2.432357e+02  1.713139e+00  1.781970e+05   8.328287e+05
# std    1.421402e+02  1.349619e+00  5.962370e+05   2.887144e+06
# min    1.000000e+00  0.000000e+00  1.000000e-02   0.000000e+00
# 25%    1.560000e+02  1.000000e+00  1.336840e+04   0.000000e+00
# 50%    2.390000e+02  1.000000e+00  7.468472e+04   1.406900e+04
# 75%    3.340000e+02  3.000000e+00  2.083648e+05   1.069695e+05
# max    7.180000e+02  4.000000e+00  9.244552e+07   4.381886e+07
#
#        newbalanceOrig  oldbalanceDest  newbalanceDest    isFraud  \
# count    6.354407e+06    6.354407e+06    6.354407e+06  6354407.0
# mean     8.559702e+05    1.101421e+06    1.224926e+06        0.0
# std      2.924987e+06    3.399202e+06    3.673816e+06        0.0
# min      0.000000e+00    0.000000e+00    0.000000e+00        0.0
# 25%      0.000000e+00    0.000000e+00    0.000000e+00        0.0
# 50%      0.000000e+00    1.333118e+05    2.148817e+05        0.0
# 75%      1.447307e+05    9.441446e+05    1.111975e+06        0.0
# max      4.368662e+07    3.560159e+08    3.561793e+08        0.0
#
#        isFlaggedFraud
# count       6354407.0
# mean              0.0
# std               0.0
# min               0.0
# 25%               0.0
# 50%               0.0
# 75%               0.0
# max               0.0

# %%
fraud.describe()
# Out:
#               step         type        amount  oldbalanceOrg  newbalanceOrig  \
# count  8213.000000  8213.000000  8.213000e+03   8.213000e+03    8.213000e+03
# mean    368.413856     2.496530  1.467967e+06   1.649668e+06    1.923926e+05
# std     216.388690     1.500087  2.404253e+06   3.547719e+06    1.965666e+06
# min       1.000000     1.000000  0.000000e+00   0.000000e+00    0.000000e+00
# 25%     181.000000     1.000000  1.270913e+05   1.258224e+05    0.000000e+00
# 50%     367.000000     1.000000  4.414234e+05   4.389835e+05    0.000000e+00
# 75%     558.000000     4.000000  1.517771e+06   1.517771e+06    0.000000e+00
# max     743.000000     4.000000  1.000000e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# count    8.213000e+03    8.213000e+03   8213.0     8213.000000
# mean     5.442496e+05    1.279708e+06      1.0        0.001948
# std      3.336421e+06    3.908817e+06      0.0        0.044097
# min      0.000000e+00    0.000000e+00      1.0        0.000000
# 25%      0.000000e+00    0.000000e+00      1.0        0.000000
# 50%      0.000000e+00    4.676420e+03      1.0        0.000000
# 75%      1.478287e+05    1.058725e+06      1.0        0.000000
# max      2.362305e+08    2.367265e+08      1.0        1.000000

# %% [markdown]
# Building a sample dataset contains similar distribution of legal and fraud transactions to avoid undersampling

# %%
legal_sample = legal.sample(n=8213)

# %%
#concatenating the two dataframes
new_dataset = pd.concat([legal_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#          step  type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 568957     23     0  360386.65   C636704368      665917.79      1026304.43
# 2500045   204     3     450.30    C48784316           0.00            0.00
# 1722564   160     1  179637.75  C1427055894           0.00            0.00
# 2789473   215     0  379026.64   C365007393     2617851.42      2996878.06
# 4350989   309     0  368433.64  C1791320921     5131139.16      5499572.80
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 568957   C1807858012       511234.31       150847.66        0               0
# 2500045  M1079474574            0.00            0.00        0               0
# 1722564   C342231390       192813.77       372451.53        0               0
# 2789473   C635281078      8746741.46      8367714.82        0               0
# 4350989  C2093967426      5621680.52      5253246.88        0               0

# %%
new_dataset.tail()
# Out:
#          step  type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 6362615   743     1   339682.13   C786484425      339682.13             0.0
# 6362616   743     4  6311409.28  C1529008245     6311409.28             0.0
# 6362617   743     1  6311409.28  C1162922333     6311409.28             0.0
# 6362618   743     4   850002.52  C1685995037      850002.52             0.0
# 6362619   743     1   850002.52  C1280323807      850002.52             0.0
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 6362615   C776919290            0.00       339682.13        1               0
# 6362616  C1881841831            0.00            0.00        1               0
# 6362617  C1365125890        68488.84      6379898.11        1               0
# 6362618  C2080388513            0.00            0.00        1               0
# 6362619   C873221189      6510099.11      7360101.63        1               0

# %%
#splitting the data into features and target and removing unnecesary columns for prediction
X = new_dataset.drop(columns=['isFraud','nameOrig','nameDest','isFlaggedFraud'], axis=1)
Y = new_dataset['isFraud']

# %%
print(X)
# Out:
#          step  type      amount  oldbalanceOrg  newbalanceOrig  \
# 568957     23     0   360386.65      665917.79      1026304.43
# 2500045   204     3      450.30           0.00            0.00
# 1722564   160     1   179637.75           0.00            0.00
# 2789473   215     0   379026.64     2617851.42      2996878.06
# 4350989   309     0   368433.64     5131139.16      5499572.80
# ...       ...   ...         ...            ...             ...
# 6362615   743     1   339682.13      339682.13            0.00
# 6362616   743     4  6311409.28     6311409.28            0.00
# 6362617   743     1  6311409.28     6311409.28            0.00
# 6362618   743     4   850002.52      850002.52            0.00
# 6362619   743     1   850002.52      850002.52            0.00
#
#          oldbalanceDest  newbalanceDest
# 568957        511234.31       150847.66
# 2500045            0.00            0.00
# 1722564       192813.77       372451.53
# 2789473      8746741.46      8367714.82
# 4350989      5621680.52      5253246.88
# ...                 ...             ...
# 6362615            0.00       339682.13
# 6362616            0.00            0.00
# 6362617        68488.84      6379898.11
# 6362618            0.00            0.00
# 6362619      6510099.11      7360101.63
#
# [16426 rows x 7 columns]

# %%
print(Y)
# Out:
# 568957     0
# 2500045    0
# 1722564    0
# 2789473    0
# 4350989    0
#           ..
# 6362615    1
# 6362616    1
# 6362617    1
# 6362618    1
# 6362619    1
# Name: isFraud, Length: 16426, dtype: int64

# %%
#splitting into training and test data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state = 2)

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((13140, 7), (3286, 7), (13140,), (3286,))

# %% [markdown]
# Model Training

# %%
classifier = LogisticRegression(max_iter = 1000)

# %%
classifier.fit(X_train,Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# Model Evaluation

# %%
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9225266362252663

# %%
X_test_prediction = classifier.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy on Test data : ', test_data_accuracy)
# Out:
# Accuracy on Test data :  0.9257455873402313

# %% [markdown]
# wrongly predicted values by our model

# %%
results = pd.DataFrame()
results['Actual'] = Y_test
results['Predicted'] = X_test_prediction
misclassified = results[results['Actual'] != results['Predicted']]
print(misclassified)
# Out:
#          Actual  Predicted
# 4667522       1          0
# 5558          1          0
# 6039712       1          0
# 3960324       1          0
# 5880708       0          1
# ...         ...        ...
# 6115985       1          0
# 4388740       1          0
# 3774434       0          1
# 1811492       0          1
# 572855        1          0
#
# [244 rows x 2 columns]

# %%
cm = confusion_matrix(Y_test,X_test_prediction)
print(cm)
# Out:
# [[1578   65]
#  [ 179 1464]]
